# %%
import pandas as pd

def low_score_red(s):  
    if s<60:
        color="red"
    else:
        color="black"
    return f'color:{color}'

def highest_score_green(col): 
    return ["background-color:lime" if s==col.max() else 'background-color:white' for s in col]

students = pd.read_excel('Students.xlsx', index_col='ID')
students.style.applymap(low_score_red,subset=['Test_1', 'Test_2', 'Test_3']).apply(highest_score_green,subset=['Test_1', 'Test_2', 'Test_3'])
# Out:
# <style  type="text/css" >
#     #T_be28201a_4409_11ed_a7fe_4c1d96487f19row0_col1 {
#             color: black;
#             background-color: white;
#         }    #T_be28201a_4409_11ed_a7fe_4c1d96487f19row0_col2 {
#             color: black;
#             background-color: white;
#         }    #T_be28201a_4409_11ed_a7fe_4c1d96487f19row0_col3 {
#             color: black;
#             background-color: white;
#         }    #T_be28201a_4409_11ed_a7fe_4c1d96487f19row1_col1 {
#             color: black;
#             background-color: white;
#         }    #T_be28201a_4409_11ed_a7fe_4c1d96487f19row1_col2 {
#             color: black;
#             background-color: lime;
#         }    #T_be28201a_4409_11ed_a7fe_4c1d96487f19row1_col3 {
#             color: black;
#             background-color: white;
#         }    #T_be28201a_4409_11ed_a7fe_4c1d96487f19row2_col1 {
#             color: red;
#             background-color: white;
# ...

# %%
import pandas as pd
import seaborn as sns

color_map=sns.light_palette('green', as_cmap=True)#调色板
students = pd.read_excel('Students.xlsx', index_col='ID')
students.style.background_gradient(color_map,subset=['Test_1', 'Test_2', 'Test_3']) #subset选择数据区域
# Out:
# <style  type="text/css" >
#     #T_ab989808_4409_11ed_b63c_4c1d96487f19row0_col1 {
#             background-color:  #c7eec7;
#             color:  #000000;
#         }    #T_ab989808_4409_11ed_b63c_4c1d96487f19row0_col2 {
#             background-color:  #3ca13c;
#             color:  #000000;
#         }    #T_ab989808_4409_11ed_b63c_4c1d96487f19row0_col3 {
#             background-color:  #48a848;
#             color:  #000000;
#         }    #T_ab989808_4409_11ed_b63c_4c1d96487f19row1_col1 {
#             background-color:  #78c278;
#             color:  #000000;
#         }    #T_ab989808_4409_11ed_b63c_4c1d96487f19row1_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_ab989808_4409_11ed_b63c_4c1d96487f19row1_col3 {
#             background-color:  #5eb45e;
#             color:  #000000;
#         }    #T_ab989808_4409_11ed_b63c_4c1d96487f19row2_col1 {
#             background-color:  #e1fde1;
#             color:  #000000;
# ...

# %%
import pandas as pd

students = pd.read_excel('Students.xlsx', index_col='ID')
students.style.bar(color="orange",subset=['Test_1', 'Test_2', 'Test_3']) #subset选择数据区域
# Out:
# <style  type="text/css" >
#     #T_ed6fb31b_4409_11ed_9b90_4c1d96487f19row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 13.6%, transparent 13.6%);
#         }    #T_ed6fb31b_4409_11ed_9b90_4c1d96487f19row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 73.8%, transparent 73.8%);
#         }    #T_ed6fb31b_4409_11ed_9b90_4c1d96487f19row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 68.5%, transparent 68.5%);
#         }    #T_ed6fb31b_4409_11ed_9b90_4c1d96487f19row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 47.7%, transparent 47.7%);
#         }    #T_ed6fb31b_4409_11ed_9b90_4c1d96487f19row1_col2 {
#             width:  10em;
#              height:  80%;
# ...
